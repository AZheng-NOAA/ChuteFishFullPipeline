# %% [markdown]
# # Step 1 - Camera Calibration
#
# First, we need a calibration clip to get camera parameters  The calibration clip should have a checker board pattern that moves around on the chute floor.

# %%
from ipywidgets import Video
Video.from_file("./videos/calibration2.mp4", width=640)
# Out:
# Video(value=b'\x00\x00\x00\x1cftypisom\x00\x00\x02\x00isomiso2mp41\x00\x00\x00\x08free\x00\xec\xb7\xd7...', wi…

# %% [markdown]
# To perform the camera calibration, we use the ../calibrate/UWEE_chute_calibration.exe executable to produce a calibration file.  To use this executable, we also need to make sure the CamCalibBEV section of the calibration parameters is correct at ../calibrate/configChuteCalibration.yml.
# ![image.png](attachment:ee9f3e96-cf9d-4a82-9777-0b8c0974f366.png)
#
#
#
# Run the terminal command and choose option 6 for camera calibration.  NOTE - this executable should only be used to generate camera calibration files.  The other options are outdated.
#
# ![image.png](attachment:f231cc05-63d0-4115-b6e8-61940db1d147.png)

# %%
# %%cmd
# "../calibrate/UWEE_chute_calibration.exe" ../calibrate/configChuteCalibration.yml
# 6
# Out:
# Microsoft Windows [Version 10.0.19045.4529]
# (c) Microsoft Corporation. All rights reserved.
#
# (yolov8) F:\ChuteFishFullPipeline\demo>"../calibrate/UWEE_chute_calibration.exe" ../calibrate/configChuteCalibration.yml
# Using configuration file: ../calibrate/configChuteCalibration.yml
# CamCalibBEV > CamCalib > CalibrationList:
# CamCalibBEV > CamCalib > CalibrationListDir:
# CamCalibBEV > CamCalib > CalibrationVideoList:
# CamCalibBEV > CamCalib > CalibrationVideoListDir: F://ChuteFishFullPipeline//demo//calibration_video
# CamCalibBEV > CamCalib > [ - ERROR - ] Cannot find the node: CameraParamFilename
# CamCalibBEV > CamCalib > nCornersPerRow: 6
# CamCalibBEV > CamCalib > nCornersPerCol: 5
# CamCalibBEV > CamCalib > gridSize: 50
# CamCalibBEV > CamCalib > scaleFactor: 0.25
# CamCalibBEV > CamCalib > cornerWindowSize: 5
# CamCalibBEV > CamCalib > numCalMax: 16
# CamCalibBEV > CalibrationListBEV:
# CamCalibBEV > CalibrationListDirBEV:
# CamCalibBEV > CalibrationVideoListBEV:
# CamCalibBEV > CalibrationVideoListDirBEV: F://ChuteFishFullPipeline//demo//calibration_video
# CamCalibBEV > CameraParamFilenameBEV: cameraParamBEV-alpha-0.2.xml
# CamCalibBEV > nCornersPerRow: 6
# CamCalibBEV > nCornersPerCol: 5
# CamCalibBEV > gridSize: 50
# CamCalibBEV > scaleFactor: 0.25
# CamCalibBEV > cornerWindowSize: 5
# CamCalibBEV > [ - ERROR - ] Cannot find the node: numCalMax
# CamCalibBEV > mBEV: 1
# CamCalibBEV > alphaBEV: 0.2
# CamCalibBEV > widthBEV: 1500
# CamCalibBEV > heightBEV: 700
# CamCalibBEV > xBEV: 450
# CamCalibBEV > yBEV: 200
# ObjSeg > GMM > method: 0
# ObjSeg > GMM > maxNumBgImgs: 100
# ObjSeg > GMM > isColorTransfer: 0
# ObjSeg > GMM > colorTransferType: 0
# ObjSeg > GMM > colorTransferCountsMax: 100
# ObjSeg > GMM > VarThreshold: 16
# ObjSeg > GMM > NMixtures: 5
# ObjSeg > GMM > BackgroundRatio: 0.9
# ObjSeg > GMM > VarThresholdGen: 9
# ObjSeg > GMM > VarInit: 15
# ObjSeg > GMM > VarMin: 4
# ObjSeg > GMM > VarMax: 75
# ObjSeg > GMM > fTau: 0.5
# ObjSeg > GMM > threshHSV: 15
# ObjSeg > GMM > aH: 1
# ObjSeg > GMM > aS: 0.1
# ObjSeg > GMM > aV: 0.2
# ObjSeg > GMM > h_bg_init: 120
# ObjSeg > GMM > h_bg_diff_thresh_init: 20
# ObjSeg > GMM > v_bg_min_init: 100
# ObjSeg > GMM > v_bg_max_init: 200
# ObjSeg > GMM > nH: 1
# ObjSeg > GMM > nS: 1.5
# ObjSeg > GMM > nV: 1.5
# ObjSeg > HistBackprojection > isUsingHSVHist: 1
# ObjSeg > HistBackprojection > nbinsB: 16
# ObjSeg > HistBackprojection > nbinsG: 16
# ObjSeg > HistBackprojection > nbinsR: 16
# ObjSeg > HistBackprojection > nbinsH: 18
# ObjSeg > HistBackprojection > nbinsS: 16
# ObjSeg > HistBackprojection > nbinsV: 16
# ObjSeg > HistBackprojection > theta: 0.8
# ObjSeg > HistBackprojection > dilationSize: 9
# ObjSeg > ActiveContour > numPoints: 200
# ObjSeg > ActiveContour > maxIterInner: 300
# ObjSeg > ActiveContour > maxIterOuter: 3
# ObjSeg > ActiveContour > wEdge: 0.6
# ObjSeg > ActiveContour > wCont: 0.15
# ObjSeg > ActiveContour > wCurv: 0.2
# ObjSeg > ActiveContour > wBall: 0.15
# ObjSeg > ActiveContour > stepSize: 9
# ObjSeg > ActiveContour > minDist: 5
# ObjSeg > ObjSegCRF > CRFinHSV: 1
# ObjSeg > ObjSegCRF > nIterations: 5
# ObjSeg > ObjSegCRF > gt_prob: 0.52
# ObjSeg > ObjSegCRF > sx: 5
# ObjSeg > ObjSegCRF > sy: 5
# ObjSeg > ObjSegCRF > wxy: 5
# ObjSeg > ObjSegCRF > sx_bgr: 60
# ObjSeg > ObjSegCRF > sy_bgr: 60
# ObjSeg > ObjSegCRF > sb_bgr: 40
# ObjSeg > ObjSegCRF > sg_bgr: 20
# ObjSeg > ObjSegCRF > sr_bgr: 20
# ObjSeg > ObjSegCRF > wbgr: 20
# ObjSeg > ObjSegCRF > sx_hsv: 30
# ObjSeg > ObjSegCRF > sy_hsv: 30
# ObjSeg > ObjSegCRF > sh_hsv: 5
# ObjSeg > ObjSegCRF > ss_hsv: 5
# ObjSeg > ObjSegCRF > sv_hsv: 10
# ObjSeg > ObjSegCRF > whsv: 20
# ObjSeg > isUsingHistBP: 0
# ObjSeg > isUsingActiveContour: 0
# ObjSeg > isUsingDenseCRF: 0
# ObjSeg > morphSESize: 5
# ObjSeg > minArea: 20000
# ObjSeg > maxArea: -1
# ObjSeg > minAspectRatio: 1
# ObjSeg > maxAspectRatio: 7
# Measurement > IsMidlineLength: 1
# Measurement > MidlinePrecision: 10
# Measurement > MidlineType: 1
# Measurement > IsBlurMeasure: 0
# Measurement > BlurMeasureThresh: 1000
# Measurement > IsEdgeMeasure: 1
# Measurement > EdgeMeasureThresh: 0.02
# Measurement > IsShowBoundingBox: 1
# Measurement > IsShowContour: 1
# Measurement > IsShowMidline: 1
# Measurement > IsShowBlurSections: 1
# Measurement > IsShowEdgeSections: 1
# InputAndOutput > InputList: img_list-sample.txt
# InputAndOutput > BackgroundList:
# InputAndOutput > GroundTruthList:
# InputAndOutput > InputListDir:
# InputAndOutput > BackgroundListDir: D:\noaa\data\chute\ChuteLabTesting\Variables\Background\
# InputAndOutput > GroundTruthListDir:
# InputAndOutput > InputVideoList:
# InputAndOutput > InputVideoListDir:
# InputAndOutput > CameraParamFilenameBEV: cameraParamBEV-alpha-0.2.xml
# InputAndOutput > ROI:
# InputAndOutput > DetectROI: 1
# InputAndOutput > DetectROIType: 2
# InputAndOutput > IsUsingShapeModel: 1
# InputAndOutput > ShapeModelPath: .\fish shape\train_data\
# InputAndOutput > NoseDirection: 0
# InputAndOutput > FixRotation: 1
# InputAndOutput > NumInitBgFrames: 100
# InputAndOutput > LearningRate: 0.005
# InputAndOutput > LearningRateFg: 0.001
# InputAndOutput > DownSampleFrames: 10
# InputAndOutput > FLower: 0.03125
# InputAndOutput > IOUThreshold: 0.2
# InputAndOutput > ROIshape: ROIshape.png
# InputAndOutput > ShapeMovementThreshold: 100
# InputAndOutput > StartImage: 0
# InputAndOutput > StopImage: -1
# InputAndOutput > CompareGT: 0
# InputAndOutput > InputDir: F://ChuteFishFullPipeline//demo//
# InputAndOutput > OutputDir: F://ChuteFishFullPipeline//demo//
# InputAndOutput > OutputFilename: length.csv
# InputAndOutput > WriteResults: 1
# InputAndOutput > WriteResultsMask: 1
# InputAndOutput > WriteResultsDemo: 0
# InputAndOutput > ShowResults: 1
# InputAndOutput > ShowResultsMask: 1
# InputAndOutput > ShowResultsDemo: 0
# InputAndOutput > WriteResultsRotatedSeg: 0
# InputAndOutput > WriteResultsRotatedSegMask: 0
# InputAndOutput > RotatedSegMarginRatio: 0.1
# InputAndOutput > nLevel: 2
#
# UWEE ChuteLogger Fish Segmentation
#   1) segmentation and length measurement
#   2) camera calibration
#   3) test background
#   4) label segmentation ground truth
#   -------------------------------------------
#   ### Video input
#   5) segmetation and length measurement
#   6) camera calibration
#   -------------------------------------------
#   7) quit
# Select one mode to continue: Reading chessboard videos ...
# F://ChuteFishFullPipeline//demo//calibration_video\calibration2.mp4
# fps = 20
# length = 300
# width = 1920
# height = 1080
# 0/300
# 1/300
# 2/300
# 3/300
# 4/300
# 5/300
# 6/300
# 7/300
# 8/300
# 9/300
# 10/300
# 11/300
# 12/300
# 13/300
# 14/300
# 15/300
# 16/300
# 17/300
# 18/300
# 19/300
# 20/300
# 21/300
# 22/300
# 23/300
# 24/300
# 25/300
# 26/300
# 27/300
# 28/300
# 29/300
# 30/300
# 31/300
# 32/300
# 33/300
# 34/300
# 35/300
# 218/300
# 219/300
# 220/300
# 221/300
# 222/300
# 223/300
# 224/300
# 225/300
# 226/300
# 227/300
# 228/300
# 229/300
# 230/300
# 231/300
# 232/300
# 233/300
# 234/300
# 235/300
# 236/300
# 237/300
# 238/300
# 239/300
# 240/300
# 241/300
# 242/300
# 243/300
# 244/300
# 245/300
# 246/300
# 247/300
# 248/300
# 249/300
# 250/300
# 251/300
# 252/300
# 253/300
# 254/300
# 255/300
# 256/300
# 257/300
# 258/300
# 259/300
# 260/300
# 261/300
# 262/300
# 263/300
# 264/300
# 265/300
# 266/300
# 267/300
# 268/300
# 269/300
# 270/300
# 271/300
# 272/300
# 273/300
# 274/300
# 275/300
# 276/300
# 277/300
# 278/300
# 279/300
# 280/300
# 281/300
# 282/300
# 283/300
# 284/300
# 285/300
# 286/300
# 287/300
# 288/300
# 289/300
# 290/300
# 291/300
# 292/300
# 293/300
# 294/300
# 295/300
# 296/300
# 297/300
# 298/300
# 299/300
# 300/300
# (60:277/300),err = 4.22341
# (60:279/300),err = 4.21203
# (60:278/300),err = 4.1657
# (60:277/300),err = 4.22241
# (60:278/300),err = 4.23774
# (60:277/300),err = 4.15896
# (60:272/300),err = 4.19807
# (60:279/300),err = 4.26962
# (60:277/300),err = 4.16188
# (60:269/300),err = 4.13305
# (60:278/300),err = 4.1657
# (60:280/300),err = 4.28995
# (60:279/300),err = 4.22394
# (60:277/300),err = 4.13867
# (60:279/300),err = 4.26962
# (60:279/300),err = 4.21203
# (60:280/300),err = 4.21217
# (60:278/300),err = 4.14306
# (60:275/300),err = 4.04547
# (60:277/300),err = 4.17626
# (60:276/300),err = 4.06816
# (60:279/300),err = 4.20297
# (60:278/300),err = 4.14693
# (60:278/300),err = 4.22346
# (60:275/300),err = 4.16696
# (60:279/300),err = 4.24948
# (60:278/300),err = 4.20654
# (60:277/300),err = 4.11335
# (60:279/300),err = 4.17096
# (60:278/300),err = 4.1657
# (60:278/300),err = 4.13893
# (60:280/300),err = 4.24031
# (60:279/300),err = 4.20297
# (60:277/300),err = 4.17714
# (60:279/300),err = 4.26962
# (60:272/300),err = 4.16058
# (60:279/300),err = 4.27242
# (60:278/300),err = 4.15193
# (60:276/300),err = 4.06816
# (60:280/300),err = 4.32306
# (60:281/300),err = 4.2658
# (60:280/300),err = 4.23773
# (60:281/300),err = 4.28969
# (60:277/300),err = 4.11872
# (60:275/300),err = 4.21832
# (60:278/300),err = 4.14693
# (60:279/300),err = 4.26518
# (60:278/300),err = 4.14013
# (60:275/300),err = 4.04433
# (60:276/300),err = 4.09914
# (60:277/300),err = 4.13228
# (60:279/300),err = 4.20336
# (60:279/300),err = 4.20146
# (60:276/300),err = 4.10055
# (60:278/300),err = 4.23343
# (60:279/300),err = 4.29592
# (60:279/300),err = 4.244
# (60:278/300),err = 4.14016
# (60:279/300),err = 4.33139
# (60:279/300),err = 4.26962
# (60:277/300),err = 4.17626
# (60:278/300),err = 4.16851
# (60:280/300),err = 4.26196
# (60:280/300),err = 4.23931
# (60:272/300),err = 3.97351
# (60:278/300),err = 4.15579
# (60:277/300),err = 4.09884
# (60:273/300),err = 3.98745
# (60:279/300),err = 4.20146
# (60:279/300),err = 4.34896
# (60:279/300),err = 4.20297
# (60:276/300),err = 4.06816
# (60:279/300),err = 4.26962
# (60:278/300),err = 4.26711
# (60:279/300),err = 4.20336
# (60:278/300),err = 4.15193
# (60:280/300),err = 4.30937
# (60:278/300),err = 4.14761
# (60:278/300),err = 4.14693
# (60:277/300),err = 4.13442
# (60:280/300),err = 4.24561
# (60:280/300),err = 4.23931
# (60:280/300),err = 4.30937
# (60:277/300),err = 4.13099
# (60:279/300),err = 4.17096
# (60:280/300),err = 4.30937
# (60:277/300),err = 4.17445
# (60:277/300),err = 4.11849
# (60:279/300),err = 4.20336
# (60:276/300),err = 4.17393
# (60:277/300),err = 4.16188
# (60:279/300),err = 4.1817
# (60:280/300),err = 4.23931
# (60:279/300),err = 4.20297
# (60:279/300),err = 4.19257
# (60:279/300),err = 4.22394
# (60:278/300),err = 4.16455
# (60:281/300),err = 4.27405
# (60:278/300),err = 4.23462
# (60:279/300),err = 4.20894
# bestErr = 3.97351
# bestErrMax = 10.0885
# (err_all, err_all_max) = (5.36109, 17.1545)
# (err_proj_all, err_proj_all_max) = (8.0009, 29.7821)
# Saving camera parameters ...
# Camera parameters is saved to F://ChuteFishFullPipeline//demo//\calibration\cameraParamBEV-alpha-0.2.xml
#
# (yolov8) F:\ChuteFishFullPipeline\demo>

# %% [markdown]
# The calibration file should be saved to F:\ChuteFishFullPipeline\demo\calibration\cameraParamBEV-alpha-0.2.xml.

# %% [markdown]
# # Step 2 - Undistort Video
# Convert video to bird's eye view (BEV) so that pixel length corresponds to real length in meters.  Here is our test video.

# %%
Video.from_file("./test_video/test2.mp4", width=640)
# Out:
# Video(value=b'\x00\x00\x00\x1cftypisom\x00\x00\x02\x00isomiso2mp41\x00\x00\x00\x08free\x00\x19x\xcb...', width…

# %% [markdown]
# Set the configuration file so that our program knows where to find the input video and where to save the output results.
# ![image.png](attachment:18a7c092-c1c2-4024-9ea9-e3ae220b41bb.png)
#
# For some reason, python can't find opencv package unless we are in the calibrate folder when running the code.

# %%
import sys
# !{sys.executable} -m pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\aotia\anaconda3\envs\yolov8\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\aotia\anaconda3\envs\yolov8\lib\site-packages (from opencv-python) (1.24.3)

# %%
# %%cmd
# "../calibrate/undistort_videos.py" --config_path demoChuteConfig.yml
# Out:
# Microsoft Windows [Version 10.0.19045.4529]
# (c) Microsoft Corporation. All rights reserved.
#
# (yolov8) F:\ChuteFishFullPipeline\demo>"../calibrate/undistort_videos.py" --config_path demoChuteConfig.yml
# Traceback (most recent call last):
#   File "F:\ChuteFishFullPipeline\calibrate\undistort_videos.py", line 1, in <module>
#     import cv2 as cv
# ModuleNotFoundError: No module named 'cv2'
# (yolov8) F:\ChuteFishFullPipeline\demo>
